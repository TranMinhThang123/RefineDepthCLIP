# %%
import os
import glob
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
path = glob.glob(os.path.join("datasets/nyu_depth_v2/official_splits/test/bathroom","sync_depth_00045.png"))
im = Image.open(path[0])
print(np.min(np.asarray(im)))
plt.imshow(im)
# Out:
# 0

# %%
path = glob.glob(os.path.join("datasets/nyu_depth_v2/official_splits/test/bathroom","rgb_00045.jpg"))
im = Image.open(path[0])
print(np.min(np.asarray(im)))
plt.imshow(im)
# Out:
# 0
